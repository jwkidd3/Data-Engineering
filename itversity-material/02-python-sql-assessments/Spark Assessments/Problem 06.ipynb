# %% [markdown]
# ## Problem 06
#
# Weightage: 25
#
# Get cities with top ten female member count from each state. There is a chance that more than 1 city might get the same rank if the counts are same. You need to get all the cities which contain top ten female member count from each state.

# %% [markdown]
# ## Data Description
#
# All of the address data is available under **/public/addresses**. Here is the schema.
# ```
# root
#  |-- address: struct (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- postal_code: string (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- street: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- ip_address: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- phone_numbers: array (nullable = true)
#  |    |-- element: string (containsNull = true)
# ```

# %% [markdown]
# ## Output Requirements
# * Place the result in the HDFS Directory
# ```
# /user/`whoami`/mock_test_02/problem06/solution
# ```
# * Use CSV and save the output to exactly one file. Make sure to preserve the header.
# * Here are the column names. Data types should be same as input data.
# ```
#  |-- state: string
#  |-- city:string
#  |-- female_count: long
# ```
# * Data should be sorted in ascending order by state and then in descending order by count.

# %% [markdown]
# ## Validation
#
# Here are the self validation steps:
# * Run the following to check number of files.
# ```
# hdfs dfs -ls /user/`whoami`/mock_test_02/problem06/solution
# ```
# * Run the following to validate the data. Review the data to see if it is sorted in ascending order by state and then in descending order by count.
# ```
# hdfs dfs -cat /user/`whoami`/mock_test_02/problem06/solution/part*
# ```
# * Run this command to get the count including header. Result should be 320.
# ```
# hdfs dfs -cat /user/`whoami`/mock_test_02/problem06/solution/part*|wc -l
# ```

# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()
spark = SparkSession. \
    builder. \
    config('spark.ui.port', '0'). \
    appName(f'Problem 06 | {username}'). \
    master('yarn'). \
    getOrCreate()

# %%
from pyspark.sql.functions import col,lit,count
data = spark.read.json("/public/addresses"). \
filter(col("gender")=='Female'). \
select("id",col('address.*')). \
groupBy("city","state"). \
agg(count(lit(1)).alias('female_count')). \
orderBy(col("state"),col("female_count").desc())

# %%
data
# Out:
# +---------------+-------+------------+
# |           city|  state|female_count|
# +---------------+-------+------------+
# |     Birmingham|Alabama|        3980|
# |     Montgomery|Alabama|        2132|
# |         Mobile|Alabama|        2093|
# |     Huntsville|Alabama|        1036|
# |     Tuscaloosa|Alabama|         544|
# |       Anniston|Alabama|         253|
# |        Gadsden|Alabama|         248|
# |      Anchorage| Alaska|        1389|
# |      Fairbanks| Alaska|         563|
# |         Juneau| Alaska|         267|
# |        Phoenix|Arizona|        4361|
# |         Tucson|Arizona|        2614|
# |           Mesa|Arizona|         779|
# |     Scottsdale|Arizona|         773|
# |       Glendale|Arizona|         521|
# |       Prescott|Arizona|         278|
# |       Chandler|Arizona|         274|
# |         Peoria|Arizona|         274|
# |        Gilbert|Arizona|         273|
# |Apache Junction|Arizona|         260|
# +---------------+-------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
spec = Window. \
    partitionBy("state"). \
    orderBy(col("state"),col("female_count").desc())

# %%
from pyspark.sql.functions import col,lit,count,dense_rank
df= data. \
withColumn("drank",dense_rank().over(spec)). \
orderBy(col('female_count').desc()). \
filter(col("drank")<=10). \
drop("drank")

# %%
df.coalesce(1).write.format('csv'). \
option('header','True'). \
mode('overwrite').save("/user/itv002480/mock_test_02/problem06/solution")

# %%
# !hdfs dfs -ls /user/`whoami`/mock_test_02/problem06/solution
# Out:
# Found 2 items
# -rw-r--r--   3 itv002480 supergroup          0 2022-06-29 05:17 /user/itv002480/mock_test_02/problem06/solution/_SUCCESS
# -rw-r--r--   3 itv002480 supergroup       7643 2022-06-29 05:17 /user/itv002480/mock_test_02/problem06/solution/part-00000-5939cbc6-b354-4ccc-809f-3c65d2bb6add-c000.csv

# %%
# !hdfs dfs -cat /user/`whoami`/mock_test_02/problem06/solution/part*
# Out:
# city,state,female_count
# Washington,District of Columbia,16238
# Houston,Texas,9998
# New York City,New York,8810
# El Paso,Texas,8353
# Dallas,Texas,6488
# Atlanta,Georgia,6468
# Sacramento,California,5500
# Los Angeles,California,5344
# Miami,Florida,5174
# Chicago,Illinois,4777
# Philadelphia,Pennsylvania,4503
# San Antonio,Texas,4493
# Phoenix,Arizona,4361
# Charlotte,North Carolina,4329
# Austin,Texas,4303
# Kansas City,Missouri,4255
# Oklahoma City,Oklahoma,4199
# San Diego,California,4187
# Denver,Colorado,4066
# Cincinnati,Ohio,4059
# Pittsburgh,Pennsylvania,3996
# Birmingham,Alabama,3980
# Las Vegas,Nevada,3923
# San Francisco,California,3729
# Minneapolis,Minnesota,3715
# Saint Louis,Missouri,3709
# Memphis,Tennessee,3689
# Richmond,Virginia,3668
# Seattle,Washington,3524
# Louisville,Kentucky,3492
# Salt Lake City,Utah,3462
# Des Moines,Iowa,3244
# San Jose,California,3221
# Orlando,Florida,3187
# New Orleans,Louisiana,3186
# Fresno,California,3176
# Tampa,Florida,3167
# Indianapolis,Indiana,3145
# Portland,Oregon,3102
# Tulsa,Oklahoma,2983
# Boston,Massachusetts,2968
# Fort Worth,Texas,2939
# Colorado Springs,Colorado,2923
# Jacksonville,Florida,2898
# Albany,New York,2781
# Dayton,Ohio,2738
# Lexington,Kentucky,2677
# Detroit,Michigan,2660
# Brooklyn,New York,2656
# Saint Paul,Minnesota,2655
# Baltimore,Maryland,2651
# Tucson,Arizona,2614
# Milwaukee,Wisconsin,2496
# Albuquerque,New Mexico,2485
# Omaha,Nebraska,2484
# Fort Lauderdale,Florida,2463
# Charleston,West Virginia,2458
# Amarillo,Texas,2454
# Rochester,New York,2450
# Nashville,Tennessee,2448
# Roanoke,Virginia,2386
# Cleveland,Ohio,2379
# Columbus,Ohio,2367
# Buffalo,New York,2304
# Honolulu,Hawaii,2304
# Raleigh,North Carolina,2189
# Fort Wayne,Indiana,2154
# Huntington,West Virginia,2151
# Baton Rouge,Louisiana,2146
# Tacoma,Washington,2134
# Montgomery,Alabama,2132
# Topeka,Kansas,2118
# Springfield,Illinois,2104
# Mobile,Alabama,2093
# Boise,Idaho,1915
# Hartford,Connecticut,1908
# Madison,Wisconsin,1898
# Wichita,Kansas,1892
# Toledo,Ohio,1889
# Evansville,Indiana,1887
# Shawnee Mission,Kansas,1886
# Jamaica,New York,1871
# Pasadena,California,1861
# Corpus Christi,Texas,1855
# Pensacola,Florida,1829
# Peoria,Illinois,1817
# Shreveport,Louisiana,1780
# Spokane,Washington,1680
# Akron,Ohio,1647
# Greensboro,North Carolina,1636
# Arlington,Virginia,1629
# Columbia,South Carolina,1619
# Erie,Pennsylvania,1613
# Jackson,Mississippi,1606
# Trenton,New Jersey,1598
# Wilmington,North Carolina,494
# Asheville,North Carolina,493
# Athens,Georgia,475
# Decatur,Georgia,472
# Monroe,Louisiana,469
# Johnstown,Pennsylvania,302
# Yakima,Washington,302
# Grand Junction,Colorado,301
# Palatine,Illinois,300
# Elizabeth,New Jersey,297
# Everett,Washington,297
# Bozeman,Montana,295
# Valley Forge,Pennsylvania,294
# Kent,Washington,291
# Camden,New Jersey,290
# Montpelier,Vermont,290
# Florence,South Carolina,288
# Englewood,Colorado,286
# Portland,Maine,286
# Lakewood,Washington,286
# Provo,Utah,284
# Columbus,Mississippi,284
# Fairfield,Connecticut,283
# Battle Creek,Michigan,283
# Meridian,Mississippi,282
# Gulfport,Mississippi,282
# Beaverton,Oregon,281
# Kingsport,Tennessee,281
# Rockville,Maryland,281
# Crawfordsville,Indiana,281
# Midland,Michigan,279
# Frankfort,Kentucky,279
# Prescott,Arizona,278
# Bloomington,Illinois,277
# Southfield,Michigan,277
# Decatur,Illinois,276
# Lees Summit,Missouri,276
# London,Kentucky,276
# Norman,Oklahoma,276
# Annapolis,Maryland,275
# Watertown,Massachusetts,275
# Peoria,Arizona,274
# Chandler,Arizona,274
# Lynn,Massachusetts,274
# Murfreesboro,Tennessee,273
# Arvada,Colorado,273
# Gaithersburg,Maryland,273
# Gilbert,Arizona,273
# Bloomington,Indiana,273
# Anderson,Indiana,272
# Aurora,Illinois,271
# New Brunswick,New Jersey,271
# Gastonia,North Carolina,271
# Woburn,Massachusetts,271
# Loretto,Minnesota,270
# Manchester,New Hampshire,270
# Warren,Ohio,270
# Sandy,Utah,269
# Eugene,Oregon,269
# Farmington,Michigan,269
# Myrtle Beach,South Carolina,269
# Springfield,Ohio,269
# Missoula,Montana,269
# Hot Springs National Park,Arkansas,268
# Iowa City,Iowa,268
# Gary,Indiana,268
# West Hartford,Connecticut,267
# Juneau,Alaska,267
# Fort Collins,Colorado,267
# Danbury,Connecticut,266
# Alexandria,Louisiana,266
# Sparks,Nevada,265
# East Saint Louis,Illinois,265
# Schaumburg,Illinois,265
# Waterloo,Iowa,265
# Las Cruces,New Mexico,265
# Lafayette,Indiana,265
# Biloxi,Mississippi,264
# Rochester,Minnesota,263
# Hagerstown,Maryland,263
# Cambridge,Massachusetts,263
# Morgantown,West Virginia,262
# Jackson,Tennessee,262
# Idaho Falls,Idaho,262
# Ridgely,Maryland,262
# Waltham,Massachusetts,261
# New Bedford,Massachusetts,261
# Apache Junction,Arizona,260
# Appleton,Wisconsin,260
# Racine,Wisconsin,260
# High Point,North Carolina,259
# Tempe,Arizona,259
# Anderson,South Carolina,257
# Aiken,South Carolina,256
# Bellevue,Washington,256
# Frederick,Maryland,256
# Pocatello,Idaho,255
# Migrate,Kentucky,254
# Anniston,Alabama,253
# Hyattsville,Maryland,253
# Bismarck,North Dakota,252
# Johnson City,Tennessee,252
# Gadsden,Alabama,248
# Hattiesburg,Mississippi,246
# Grand Forks,North Dakota,243
# Cheyenne,Wyoming,241
# Beaufort,South Carolina,239
# Saint Joseph,Missouri,238
# Edmond,Oklahoma,235
# Independence,Missouri,230
# Helena,Montana,230

# %%
# !hdfs dfs -cat /user/`whoami`/mock_test_02/problem06/solution/part*|wc -l
# Out:
# 320
